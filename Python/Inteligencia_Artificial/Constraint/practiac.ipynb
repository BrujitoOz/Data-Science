# %% [markdown]
# # Or-tools

# %% [markdown]
# ## Linear Optimization

# %% [markdown]
# ### LP problems

# %%
from ortools.linear_solver import pywraplp

# %%
solver = pywraplp.Solver.CreateSolver('GLOP')

# %%
x = solver.NumVar(0, solver.infinity(), 'x')
y = solver.NumVar(0, solver.infinity(), 'y')

print('Number of variables =', solver.NumVariables())
# Out:
# Number of variables = 2

# %%
# Constraint 0: x + 2y <= 14.
solver.Add(x + 2 * y <= 14)

# Constraint 1: 3x - y >= 0.
solver.Add(3 * x - y >= 0)

# Constraint 2: x - y <= 2.
solver.Add(x - y <= 2)

print('Number of constraints =', solver.NumConstraints())
# Out:
# Number of constraints = 9

# %%
# Objective function: 3x + 4y.
solver.Maximize(3 * x + 4 * y)
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Objective value =', solver.Objective().Value())
    print('x =', x.solution_value())
    print('y =', y.solution_value())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Solution:
# Objective value = 33.99999999999999
# x = 5.999999999999998
# y = 3.9999999999999996

# %% [markdown]
# ### The Stigler Diet Problem

# %%
from ortools.linear_solver import pywraplp

# %%
# Nutrient minimums.
nutrients = [
    ['Calories (kcal)', 3],
    ['Protein (g)', 70],
    ['Calcium (g)', 0.8],
    ['Iron (mg)', 12],
    ['Vitamin A (KIU)', 5],
    ['Vitamin B1 (mg)', 1.8],
    ['Vitamin B2 (mg)', 2.7],
    ['Niacin (mg)', 18],
    ['Vitamin C (mg)', 75],
]
data = [
    [
        'Wheat Flour (Enriched)', '10 lb.', 36, 44.7, 1411, 2, 365, 0, 55.4,
        33.3, 441, 0
    ],
    ['Macaroni', '1 lb.', 14.1, 11.6, 418, 0.7, 54, 0, 3.2, 1.9, 68, 0],
    [
        'Wheat Cereal (Enriched)', '28 oz.', 24.2, 11.8, 377, 14.4, 175, 0,
        14.4, 8.8, 114, 0
    ],
    ['Corn Flakes', '8 oz.', 7.1, 11.4, 252, 0.1, 56, 0, 13.5, 2.3, 68, 0],
    [
        'Corn Meal', '1 lb.', 4.6, 36.0, 897, 1.7, 99, 30.9, 17.4, 7.9, 106,
        0
    ],
    [
        'Hominy Grits', '24 oz.', 8.5, 28.6, 680, 0.8, 80, 0, 10.6, 1.6,
        110, 0
    ],
    ['Rice', '1 lb.', 7.5, 21.2, 460, 0.6, 41, 0, 2, 4.8, 60, 0],
    ['Rolled Oats', '1 lb.', 7.1, 25.3, 907, 5.1, 341, 0, 37.1, 8.9, 64, 0],
    [
        'White Bread (Enriched)', '1 lb.', 7.9, 15.0, 488, 2.5, 115, 0,
        13.8, 8.5, 126, 0
    ],
    [
        'Whole Wheat Bread', '1 lb.', 9.1, 12.2, 484, 2.7, 125, 0, 13.9,
        6.4, 160, 0
    ],
    ['Rye Bread', '1 lb.', 9.1, 12.4, 439, 1.1, 82, 0, 9.9, 3, 66, 0],
    ['Pound Cake', '1 lb.', 24.8, 8.0, 130, 0.4, 31, 18.9, 2.8, 3, 17, 0],
    ['Soda Crackers', '1 lb.', 15.1, 12.5, 288, 0.5, 50, 0, 0, 0, 0, 0],
    ['Milk', '1 qt.', 11, 6.1, 310, 10.5, 18, 16.8, 4, 16, 7, 177],
    [
        'Evaporated Milk (can)', '14.5 oz.', 6.7, 8.4, 422, 15.1, 9, 26, 3,
        23.5, 11, 60
    ],
    ['Butter', '1 lb.', 30.8, 10.8, 9, 0.2, 3, 44.2, 0, 0.2, 2, 0],
    ['Oleomargarine', '1 lb.', 16.1, 20.6, 17, 0.6, 6, 55.8, 0.2, 0, 0, 0],
    ['Eggs', '1 doz.', 32.6, 2.9, 238, 1.0, 52, 18.6, 2.8, 6.5, 1, 0],
    [
        'Cheese (Cheddar)', '1 lb.', 24.2, 7.4, 448, 16.4, 19, 28.1, 0.8,
        10.3, 4, 0
    ],
    ['Cream', '1/2 pt.', 14.1, 3.5, 49, 1.7, 3, 16.9, 0.6, 2.5, 0, 17],
    [
        'Peanut Butter', '1 lb.', 17.9, 15.7, 661, 1.0, 48, 0, 9.6, 8.1,
        471, 0
    ],
    ['Mayonnaise', '1/2 pt.', 16.7, 8.6, 18, 0.2, 8, 2.7, 0.4, 0.5, 0, 0],
    ['Crisco', '1 lb.', 20.3, 20.1, 0, 0, 0, 0, 0, 0, 0, 0],
    ['Lard', '1 lb.', 9.8, 41.7, 0, 0, 0, 0.2, 0, 0.5, 5, 0],
    [
        'Sirloin Steak', '1 lb.', 39.6, 2.9, 166, 0.1, 34, 0.2, 2.1, 2.9,
        69, 0
    ],
    ['Round Steak', '1 lb.', 36.4, 2.2, 214, 0.1, 32, 0.4, 2.5, 2.4, 87, 0],
    ['Rib Roast', '1 lb.', 29.2, 3.4, 213, 0.1, 33, 0, 0, 2, 0, 0],
    ['Chuck Roast', '1 lb.', 22.6, 3.6, 309, 0.2, 46, 0.4, 1, 4, 120, 0],
    ['Plate', '1 lb.', 14.6, 8.5, 404, 0.2, 62, 0, 0.9, 0, 0, 0],
    [
        'Liver (Beef)', '1 lb.', 26.8, 2.2, 333, 0.2, 139, 169.2, 6.4, 50.8,
        316, 525
    ],
    ['Leg of Lamb', '1 lb.', 27.6, 3.1, 245, 0.1, 20, 0, 2.8, 3.9, 86, 0],
    [
        'Lamb Chops (Rib)', '1 lb.', 36.6, 3.3, 140, 0.1, 15, 0, 1.7, 2.7,
        54, 0
    ],
    ['Pork Chops', '1 lb.', 30.7, 3.5, 196, 0.2, 30, 0, 17.4, 2.7, 60, 0],
    [
        'Pork Loin Roast', '1 lb.', 24.2, 4.4, 249, 0.3, 37, 0, 18.2, 3.6,
        79, 0
    ],
    ['Bacon', '1 lb.', 25.6, 10.4, 152, 0.2, 23, 0, 1.8, 1.8, 71, 0],
    ['Ham, smoked', '1 lb.', 27.4, 6.7, 212, 0.2, 31, 0, 9.9, 3.3, 50, 0],
    ['Salt Pork', '1 lb.', 16, 18.8, 164, 0.1, 26, 0, 1.4, 1.8, 0, 0],
    [
        'Roasting Chicken', '1 lb.', 30.3, 1.8, 184, 0.1, 30, 0.1, 0.9, 1.8,
        68, 46
    ],
    ['Veal Cutlets', '1 lb.', 42.3, 1.7, 156, 0.1, 24, 0, 1.4, 2.4, 57, 0],
    [
        'Salmon, Pink (can)', '16 oz.', 13, 5.8, 705, 6.8, 45, 3.5, 1, 4.9,
        209, 0
    ],
    ['Apples', '1 lb.', 4.4, 5.8, 27, 0.5, 36, 7.3, 3.6, 2.7, 5, 544],
    ['Bananas', '1 lb.', 6.1, 4.9, 60, 0.4, 30, 17.4, 2.5, 3.5, 28, 498],
    ['Lemons', '1 doz.', 26, 1.0, 21, 0.5, 14, 0, 0.5, 0, 4, 952],
    ['Oranges', '1 doz.', 30.9, 2.2, 40, 1.1, 18, 11.1, 3.6, 1.3, 10, 1998],
    ['Green Beans', '1 lb.', 7.1, 2.4, 138, 3.7, 80, 69, 4.3, 5.8, 37, 862],
    ['Cabbage', '1 lb.', 3.7, 2.6, 125, 4.0, 36, 7.2, 9, 4.5, 26, 5369],
    ['Carrots', '1 bunch', 4.7, 2.7, 73, 2.8, 43, 188.5, 6.1, 4.3, 89, 608],
    ['Celery', '1 stalk', 7.3, 0.9, 51, 3.0, 23, 0.9, 1.4, 1.4, 9, 313],
    ['Lettuce', '1 head', 8.2, 0.4, 27, 1.1, 22, 112.4, 1.8, 3.4, 11, 449],
    ['Onions', '1 lb.', 3.6, 5.8, 166, 3.8, 59, 16.6, 4.7, 5.9, 21, 1184],
    [
        'Potatoes', '15 lb.', 34, 14.3, 336, 1.8, 118, 6.7, 29.4, 7.1, 198,
        2522
    ],
    ['Spinach', '1 lb.', 8.1, 1.1, 106, 0, 138, 918.4, 5.7, 13.8, 33, 2755],
    [
        'Sweet Potatoes', '1 lb.', 5.1, 9.6, 138, 2.7, 54, 290.7, 8.4, 5.4,
        83, 1912
    ],
    [
        'Peaches (can)', 'No. 2 1/2', 16.8, 3.7, 20, 0.4, 10, 21.5, 0.5, 1,
        31, 196
    ],
    [
        'Pears (can)', 'No. 2 1/2', 20.4, 3.0, 8, 0.3, 8, 0.8, 0.8, 0.8, 5,
        81
    ],
    [
        'Pineapple (can)', 'No. 2 1/2', 21.3, 2.4, 16, 0.4, 8, 2, 2.8, 0.8,
        7, 399
    ],
    [
        'Asparagus (can)', 'No. 2', 27.7, 0.4, 33, 0.3, 12, 16.3, 1.4, 2.1,
        17, 272
    ],
    [
        'Green Beans (can)', 'No. 2', 10, 1.0, 54, 2, 65, 53.9, 1.6, 4.3,
        32, 431
    ],
    [
        'Pork and Beans (can)', '16 oz.', 7.1, 7.5, 364, 4, 134, 3.5, 8.3,
        7.7, 56, 0
    ],
    ['Corn (can)', 'No. 2', 10.4, 5.2, 136, 0.2, 16, 12, 1.6, 2.7, 42, 218],
    [
        'Peas (can)', 'No. 2', 13.8, 2.3, 136, 0.6, 45, 34.9, 4.9, 2.5, 37,
        370
    ],
    [
        'Tomatoes (can)', 'No. 2', 8.6, 1.3, 63, 0.7, 38, 53.2, 3.4, 2.5,
        36, 1253
    ],
    [
        'Tomato Soup (can)', '10 1/2 oz.', 7.6, 1.6, 71, 0.6, 43, 57.9, 3.5,
        2.4, 67, 862
    ],
    [
        'Peaches, Dried', '1 lb.', 15.7, 8.5, 87, 1.7, 173, 86.8, 1.2, 4.3,
        55, 57
    ],
    [
        'Prunes, Dried', '1 lb.', 9, 12.8, 99, 2.5, 154, 85.7, 3.9, 4.3, 65,
        257
    ],
    [
        'Raisins, Dried', '15 oz.', 9.4, 13.5, 104, 2.5, 136, 4.5, 6.3, 1.4,
        24, 136
    ],
    [
        'Peas, Dried', '1 lb.', 7.9, 20.0, 1367, 4.2, 345, 2.9, 28.7, 18.4,
        162, 0
    ],
    [
        'Lima Beans, Dried', '1 lb.', 8.9, 17.4, 1055, 3.7, 459, 5.1, 26.9,
        38.2, 93, 0
    ],
    [
        'Navy Beans, Dried', '1 lb.', 5.9, 26.9, 1691, 11.4, 792, 0, 38.4,
        24.6, 217, 0
    ],
    ['Coffee', '1 lb.', 22.4, 0, 0, 0, 0, 0, 4, 5.1, 50, 0],
    ['Tea', '1/4 lb.', 17.4, 0, 0, 0, 0, 0, 0, 2.3, 42, 0],
    ['Cocoa', '8 oz.', 8.6, 8.7, 237, 3, 72, 0, 2, 11.9, 40, 0],
    ['Chocolate', '8 oz.', 16.2, 8.0, 77, 1.3, 39, 0, 0.9, 3.4, 14, 0],
    ['Sugar', '10 lb.', 51.7, 34.9, 0, 0, 0, 0, 0, 0, 0, 0],
    ['Corn Syrup', '24 oz.', 13.7, 14.7, 0, 0.5, 74, 0, 0, 0, 5, 0],
    ['Molasses', '18 oz.', 13.6, 9.0, 0, 10.3, 244, 0, 1.9, 7.5, 146, 0],
    [
        'Strawberry Preserves', '1 lb.', 20.5, 6.4, 11, 0.4, 7, 0.2, 0.2,
        0.4, 3, 0
    ],
]

# %%
solver = pywraplp.Solver('StiglerDietExample', pywraplp.Solver.GLOP_LINEAR_PROGRAMMING)

# %%
foods = [solver.NumVar(0.0, solver.infinity(), item[0]) for item in data]
print('Number of variables =', solver.NumVariables())
# Out:
# Number of variables = 77

# %%
print([item[0] for item in data])
# Out:
# ['Wheat Flour (Enriched)', 'Macaroni', 'Wheat Cereal (Enriched)', 'Corn Flakes', 'Corn Meal', 'Hominy Grits', 'Rice', 'Rolled Oats', 'White Bread (Enriched)', 'Whole Wheat Bread', 'Rye Bread', 'Pound Cake', 'Soda Crackers', 'Milk', 'Evaporated Milk (can)', 'Butter', 'Oleomargarine', 'Eggs', 'Cheese (Cheddar)', 'Cream', 'Peanut Butter', 'Mayonnaise', 'Crisco', 'Lard', 'Sirloin Steak', 'Round Steak', 'Rib Roast', 'Chuck Roast', 'Plate', 'Liver (Beef)', 'Leg of Lamb', 'Lamb Chops (Rib)', 'Pork Chops', 'Pork Loin Roast', 'Bacon', 'Ham, smoked', 'Salt Pork', 'Roasting Chicken', 'Veal Cutlets', 'Salmon, Pink (can)', 'Apples', 'Bananas', 'Lemons', 'Oranges', 'Green Beans', 'Cabbage', 'Carrots', 'Celery', 'Lettuce', 'Onions', 'Potatoes', 'Spinach', 'Sweet Potatoes', 'Peaches (can)', 'Pears (can)', 'Pineapple (can)', 'Asparagus (can)', 'Green Beans (can)', 'Pork and Beans (can)', 'Corn (can)', 'Peas (can)', 'Tomatoes (can)', 'Tomato Soup (can)', 'Peaches, Dried', 'Prunes, Dried', 'Raisins, Dried', 'Peas, Dried', 'Lima Beans, Dried', 'Navy Beans, Dried', 'Coffee', 'Tea', 'Cocoa', 'Chocolate', 'Sugar', 'Corn Syrup', 'Molasses', 'Strawberry Preserves']

# %%
# Create the constraints, one per nutrient.
constraints = []
for i, nutrient in enumerate(nutrients):
    constraints.append(solver.Constraint(nutrient[1], solver.infinity()))
    print(nutrient[1])
    for j, item in enumerate(data):
        constraints[i].SetCoefficient(foods[j], item[i + 3])
        print(foods[j], item[i+3])

print('Number of constraints =', solver.NumConstraints())
# Out:
# 3
# Wheat Flour (Enriched) 44.7
# Macaroni 11.6
# Wheat Cereal (Enriched) 11.8
# Corn Flakes 11.4
# Corn Meal 36.0
# Hominy Grits 28.6
# Rice 21.2
# Rolled Oats 25.3
# White Bread (Enriched) 15.0
# Whole Wheat Bread 12.2
# Rye Bread 12.4
# Pound Cake 8.0
# Soda Crackers 12.5
# Milk 6.1
# Evaporated Milk (can) 8.4
# Butter 10.8
# Oleomargarine 20.6
# Eggs 2.9
# Cheese (Cheddar) 7.4
# Cream 3.5
# Peanut Butter 15.7
# Mayonnaise 8.6
# Crisco 20.1
# Lard 41.7
# Sirloin Steak 2.9
# Round Steak 2.2
# Rib Roast 3.4
# Chuck Roast 3.6
# Plate 8.5
# Liver (Beef) 2.2
# Leg of Lamb 3.1
# Lamb Chops (Rib) 3.3
# Pork Chops 3.5
# Pork Loin Roast 4.4
# Bacon 10.4
# Ham, smoked 6.7
# Salt Pork 18.8
# Roasting Chicken 1.8
# Veal Cutlets 1.7
# Salmon, Pink (can) 5.8
# Apples 5.8
# Bananas 4.9
# Lemons 1.0
# Oranges 2.2
# Green Beans 2.4
# Cabbage 2.6
# Carrots 2.7
# Celery 0.9
# Lettuce 0.4
# Onions 5.8
# Potatoes 14.3
# Spinach 1.1
# Sweet Potatoes 9.6
# Peaches (can) 3.7
# Pears (can) 3.0
# Pineapple (can) 2.4
# Asparagus (can) 0.4
# Green Beans (can) 1.0
# Pork and Beans (can) 7.5
# Corn (can) 5.2
# Peas (can) 2.3
# Tomatoes (can) 1.3
# Tomato Soup (can) 1.6
# Peaches, Dried 8.5
# Prunes, Dried 12.8
# Raisins, Dried 13.5
# Peas, Dried 20.0
# Lima Beans, Dried 17.4
# Navy Beans, Dried 26.9
# Coffee 0
# Tea 0
# Cocoa 8.7
# Chocolate 8.0
# Sugar 34.9
# Corn Syrup 14.7
# Molasses 9.0
# Strawberry Preserves 6.4
# 70
# Wheat Flour (Enriched) 1411
# Macaroni 418
# Wheat Cereal (Enriched) 377
# Corn Flakes 252
# Corn Meal 897
# Hominy Grits 680
# Rice 460
# Rolled Oats 907
# White Bread (Enriched) 488
# Whole Wheat Bread 484
# Rye Bread 439
# Pound Cake 130
# Soda Crackers 288
# Milk 310
# Evaporated Milk (can) 422
# Butter 9
# Oleomargarine 17
# Eggs 238
# Cheese (Cheddar) 448
# Cream 49
# Peanut Butter 661
# Mayonnaise 18
# Crisco 0
# Lard 0
# Sirloin Steak 166
# Round Steak 214
# Rib Roast 213
# Chuck Roast 309
# Plate 404
# Liver (Beef) 333
# Leg of Lamb 245
# Lamb Chops (Rib) 140
# Pork Chops 196
# Pork Loin Roast 249
# Bacon 152
# Ham, smoked 212
# Salt Pork 164
# Roasting Chicken 184
# Veal Cutlets 156
# Salmon, Pink (can) 705
# Apples 27
# Bananas 60
# Lemons 21
# Oranges 40
# Green Beans 138
# Cabbage 125
# Carrots 73
# Celery 51
# Lettuce 27
# Onions 166
# Potatoes 336
# Spinach 106
# Sweet Potatoes 138
# Peaches (can) 20
# Pears (can) 8
# Pineapple (can) 16
# Asparagus (can) 33
# Green Beans (can) 54
# Pork and Beans (can) 364
# Corn (can) 136
# Peas (can) 136
# Tomatoes (can) 63
# Tomato Soup (can) 71
# Peaches, Dried 87
# Prunes, Dried 99
# Raisins, Dried 104
# Peas, Dried 1367
# Lima Beans, Dried 1055
# Navy Beans, Dried 1691
# Coffee 0
# Tea 0
# Cocoa 237
# Chocolate 77
# Sugar 0
# Corn Syrup 0
# Molasses 0
# Strawberry Preserves 11
# 0.8
# Wheat Flour (Enriched) 2
# Macaroni 0.7
# Wheat Cereal (Enriched) 14.4
# Corn Flakes 0.1
# Corn Meal 1.7
# Hominy Grits 0.8
# Rice 0.6
# Rolled Oats 5.1
# White Bread (Enriched) 2.5
# Whole Wheat Bread 2.7
# Rye Bread 1.1
# Pound Cake 0.4
# Soda Crackers 0.5
# Milk 10.5
# Evaporated Milk (can) 15.1
# Butter 0.2
# Oleomargarine 0.6
# Eggs 1.0
# Cheese (Cheddar) 16.4
# Cream 1.7
# Peanut Butter 1.0
# Mayonnaise 0.2
# Crisco 0
# Lard 0
# Sirloin Steak 0.1
# Round Steak 0.1
# Rib Roast 0.1
# Chuck Roast 0.2
# Plate 0.2
# Liver (Beef) 0.2
# Leg of Lamb 0.1
# Lamb Chops (Rib) 0.1
# Pork Chops 0.2
# Pork Loin Roast 0.3
# Bacon 0.2
# Ham, smoked 0.2
# Salt Pork 0.1
# Roasting Chicken 0.1
# Veal Cutlets 0.1
# Salmon, Pink (can) 6.8
# Apples 0.5
# Bananas 0.4
# Lemons 0.5
# Oranges 1.1
# Green Beans 3.7
# Cabbage 4.0
# Carrots 2.8
# Celery 3.0
# Lettuce 1.1
# Onions 3.8
# Potatoes 1.8
# Spinach 0
# Sweet Potatoes 2.7
# Peaches (can) 0.4
# Pears (can) 0.3
# Pineapple (can) 0.4
# Asparagus (can) 0.3
# Green Beans (can) 2
# Pork and Beans (can) 4
# Corn (can) 0.2
# Peas (can) 0.6
# Tomatoes (can) 0.7
# Tomato Soup (can) 0.6
# Peaches, Dried 1.7
# Prunes, Dried 2.5
# Raisins, Dried 2.5
# Peas, Dried 4.2
# Lima Beans, Dried 3.7
# Navy Beans, Dried 11.4
# Coffee 0
# Tea 0
# Cocoa 3
# Chocolate 1.3
# Sugar 0
# Corn Syrup 0.5
# Molasses 10.3
# Strawberry Preserves 0.4
# 12
# Wheat Flour (Enriched) 365
# Macaroni 54
# Wheat Cereal (Enriched) 175
# Corn Flakes 56
# Corn Meal 99
# Hominy Grits 80
# Rice 41
# Rolled Oats 341
# White Bread (Enriched) 115
# Whole Wheat Bread 125
# Rye Bread 82
# Pound Cake 31
# Soda Crackers 50
# Milk 18
# Evaporated Milk (can) 9
# Butter 3
# Oleomargarine 6
# Eggs 52
# Cheese (Cheddar) 19
# Cream 3
# Peanut Butter 48
# Mayonnaise 8
# Crisco 0
# Lard 0
# Sirloin Steak 34
# Round Steak 32
# Rib Roast 33
# Chuck Roast 46
# Plate 62
# Liver (Beef) 139
# Leg of Lamb 20
# Lamb Chops (Rib) 15
# Pork Chops 30
# Pork Loin Roast 37
# Bacon 23
# Ham, smoked 31
# Salt Pork 26
# Roasting Chicken 30
# Veal Cutlets 24
# Salmon, Pink (can) 45
# Apples 36
# Bananas 30
# Lemons 14
# Oranges 18
# Green Beans 80
# Cabbage 36
# Carrots 43
# Celery 23
# Lettuce 22
# Onions 59
# Potatoes 118
# Spinach 138
# Sweet Potatoes 54
# Peaches (can) 10
# Pears (can) 8
# Pineapple (can) 8
# Asparagus (can) 12
# Green Beans (can) 65
# Pork and Beans (can) 134
# Corn (can) 16
# Peas (can) 45
# Tomatoes (can) 38
# Tomato Soup (can) 43
# Peaches, Dried 173
# Prunes, Dried 154
# Raisins, Dried 136
# Peas, Dried 345
# Lima Beans, Dried 459
# Navy Beans, Dried 792
# Coffee 0
# Tea 0
# Cocoa 72
# Chocolate 39
# Sugar 0
# Corn Syrup 74
# Molasses 244
# Strawberry Preserves 7
# 5
# Wheat Flour (Enriched) 0
# Macaroni 0
# Wheat Cereal (Enriched) 0
# Corn Flakes 0
# Corn Meal 30.9
# Hominy Grits 0
# Rice 0
# Rolled Oats 0
# White Bread (Enriched) 0
# Whole Wheat Bread 0
# Rye Bread 0
# Pound Cake 18.9
# Soda Crackers 0
# Milk 16.8
# Evaporated Milk (can) 26
# Butter 44.2
# Oleomargarine 55.8
# Eggs 18.6
# Cheese (Cheddar) 28.1
# Cream 16.9
# Peanut Butter 0
# Mayonnaise 2.7
# Crisco 0
# Lard 0.2
# Sirloin Steak 0.2
# Round Steak 0.4
# Rib Roast 0
# Chuck Roast 0.4
# Plate 0
# Liver (Beef) 169.2
# Leg of Lamb 0
# Lamb Chops (Rib) 0
# Pork Chops 0
# Pork Loin Roast 0
# Bacon 0
# Ham, smoked 0
# Salt Pork 0
# Roasting Chicken 0.1
# Veal Cutlets 0
# Salmon, Pink (can) 3.5
# Apples 7.3
# Bananas 17.4
# Lemons 0
# Oranges 11.1
# Green Beans 69
# Cabbage 7.2
# Carrots 188.5
# Celery 0.9
# Lettuce 112.4
# Onions 16.6
# Potatoes 6.7
# Spinach 918.4
# Sweet Potatoes 290.7
# Peaches (can) 21.5
# Pears (can) 0.8
# Pineapple (can) 2
# Asparagus (can) 16.3
# Green Beans (can) 53.9
# Pork and Beans (can) 3.5
# Corn (can) 12
# Peas (can) 34.9
# Tomatoes (can) 53.2
# Tomato Soup (can) 57.9
# Peaches, Dried 86.8
# Prunes, Dried 85.7
# Raisins, Dried 4.5
# Peas, Dried 2.9
# Lima Beans, Dried 5.1
# Navy Beans, Dried 0
# Coffee 0
# Tea 0
# Cocoa 0
# Chocolate 0
# Sugar 0
# Corn Syrup 0
# Molasses 0
# Strawberry Preserves 0.2
# 1.8
# Wheat Flour (Enriched) 55.4
# Macaroni 3.2
# Wheat Cereal (Enriched) 14.4
# Corn Flakes 13.5
# Corn Meal 17.4
# Hominy Grits 10.6
# Rice 2
# Rolled Oats 37.1
# White Bread (Enriched) 13.8
# Whole Wheat Bread 13.9
# Rye Bread 9.9
# Pound Cake 2.8
# Soda Crackers 0
# Milk 4
# Evaporated Milk (can) 3
# Butter 0
# Oleomargarine 0.2
# Eggs 2.8
# Cheese (Cheddar) 0.8
# Cream 0.6
# Peanut Butter 9.6
# Mayonnaise 0.4
# Crisco 0
# Lard 0
# Sirloin Steak 2.1
# Round Steak 2.5
# Rib Roast 0
# Chuck Roast 1
# Plate 0.9
# Liver (Beef) 6.4
# Leg of Lamb 2.8
# Lamb Chops (Rib) 1.7
# Pork Chops 17.4
# Pork Loin Roast 18.2
# Bacon 1.8
# Ham, smoked 9.9
# Salt Pork 1.4
# Roasting Chicken 0.9
# Veal Cutlets 1.4
# Salmon, Pink (can) 1
# Apples 3.6
# Bananas 2.5
# Lemons 0.5
# Oranges 3.6
# Green Beans 4.3
# Cabbage 9
# Carrots 6.1
# Celery 1.4
# Lettuce 1.8
# Onions 4.7
# Potatoes 29.4
# Spinach 5.7
# Sweet Potatoes 8.4
# Peaches (can) 0.5
# Pears (can) 0.8
# Pineapple (can) 2.8
# Asparagus (can) 1.4
# Green Beans (can) 1.6
# Pork and Beans (can) 8.3
# Corn (can) 1.6
# Peas (can) 4.9
# Tomatoes (can) 3.4
# Tomato Soup (can) 3.5
# Peaches, Dried 1.2
# Prunes, Dried 3.9
# Raisins, Dried 6.3
# Peas, Dried 28.7
# Lima Beans, Dried 26.9
# Navy Beans, Dried 38.4
# Coffee 4
# Tea 0
# Cocoa 2
# Chocolate 0.9
# Sugar 0
# Corn Syrup 0
# Molasses 1.9
# Strawberry Preserves 0.2
# 2.7
# Wheat Flour (Enriched) 33.3
# Macaroni 1.9
# Wheat Cereal (Enriched) 8.8
# Corn Flakes 2.3
# Corn Meal 7.9
# Hominy Grits 1.6
# Rice 4.8
# Rolled Oats 8.9
# White Bread (Enriched) 8.5
# Whole Wheat Bread 6.4
# Rye Bread 3
# Pound Cake 3
# Soda Crackers 0
# Milk 16
# Evaporated Milk (can) 23.5
# Butter 0.2
# Oleomargarine 0
# Eggs 6.5
# Cheese (Cheddar) 10.3
# Cream 2.5
# Peanut Butter 8.1
# Mayonnaise 0.5
# Crisco 0
# Lard 0.5
# Sirloin Steak 2.9
# Round Steak 2.4
# Rib Roast 2
# Chuck Roast 4
# Plate 0
# Liver (Beef) 50.8
# Leg of Lamb 3.9
# Lamb Chops (Rib) 2.7
# Pork Chops 2.7
# Pork Loin Roast 3.6
# Bacon 1.8
# Ham, smoked 3.3
# Salt Pork 1.8
# Roasting Chicken 1.8
# Veal Cutlets 2.4
# Salmon, Pink (can) 4.9
# Apples 2.7
# Bananas 3.5
# Lemons 0
# Oranges 1.3
# Green Beans 5.8
# Cabbage 4.5
# Carrots 4.3
# Celery 1.4
# Lettuce 3.4
# Onions 5.9
# Potatoes 7.1
# Spinach 13.8
# Sweet Potatoes 5.4
# Peaches (can) 1
# Pears (can) 0.8
# Pineapple (can) 0.8
# Asparagus (can) 2.1
# Green Beans (can) 4.3
# Pork and Beans (can) 7.7
# Corn (can) 2.7
# Peas (can) 2.5
# Tomatoes (can) 2.5
# Tomato Soup (can) 2.4
# Peaches, Dried 4.3
# Prunes, Dried 4.3
# Raisins, Dried 1.4
# Peas, Dried 18.4
# Lima Beans, Dried 38.2
# Navy Beans, Dried 24.6
# Coffee 5.1
# Tea 2.3
# Cocoa 11.9
# Chocolate 3.4
# Sugar 0
# Corn Syrup 0
# Molasses 7.5
# Strawberry Preserves 0.4
# 18
# Wheat Flour (Enriched) 441
# Macaroni 68
# Wheat Cereal (Enriched) 114
# Corn Flakes 68
# Corn Meal 106
# Hominy Grits 110
# Rice 60
# Rolled Oats 64
# White Bread (Enriched) 126
# Whole Wheat Bread 160
# Rye Bread 66
# Pound Cake 17
# Soda Crackers 0
# Milk 7
# Evaporated Milk (can) 11
# Butter 2
# Oleomargarine 0
# Eggs 1
# Cheese (Cheddar) 4
# Cream 0
# Peanut Butter 471
# Mayonnaise 0
# Crisco 0
# Lard 5
# Sirloin Steak 69
# Round Steak 87
# Rib Roast 0
# Chuck Roast 120
# Plate 0
# Liver (Beef) 316
# Leg of Lamb 86
# Lamb Chops (Rib) 54
# Pork Chops 60
# Pork Loin Roast 79
# Bacon 71
# Ham, smoked 50
# Salt Pork 0
# Roasting Chicken 68
# Veal Cutlets 57
# Salmon, Pink (can) 209
# Apples 5
# Bananas 28
# Lemons 4
# Oranges 10
# Green Beans 37
# Cabbage 26
# Carrots 89
# Celery 9
# Lettuce 11
# Onions 21
# Potatoes 198
# Spinach 33
# Sweet Potatoes 83
# Peaches (can) 31
# Pears (can) 5
# Pineapple (can) 7
# Asparagus (can) 17
# Green Beans (can) 32
# Pork and Beans (can) 56
# Corn (can) 42
# Peas (can) 37
# Tomatoes (can) 36
# Tomato Soup (can) 67
# Peaches, Dried 55
# Prunes, Dried 65
# Raisins, Dried 24
# Peas, Dried 162
# Lima Beans, Dried 93
# Navy Beans, Dried 217
# Coffee 50
# Tea 42
# Cocoa 40
# Chocolate 14
# Sugar 0
# Corn Syrup 5
# Molasses 146
# Strawberry Preserves 3
# 75
# Wheat Flour (Enriched) 0
# Macaroni 0
# Wheat Cereal (Enriched) 0
# Corn Flakes 0
# Corn Meal 0
# Hominy Grits 0
# Rice 0
# Rolled Oats 0
# White Bread (Enriched) 0
# Whole Wheat Bread 0
# Rye Bread 0
# Pound Cake 0
# Soda Crackers 0
# Milk 177
# Evaporated Milk (can) 60
# Butter 0
# Oleomargarine 0
# Eggs 0
# Cheese (Cheddar) 0
# Cream 17
# Peanut Butter 0
# Mayonnaise 0
# Crisco 0
# Lard 0
# Sirloin Steak 0
# Round Steak 0
# Rib Roast 0
# Chuck Roast 0
# Plate 0
# Liver (Beef) 525
# Leg of Lamb 0
# Lamb Chops (Rib) 0
# Pork Chops 0
# Pork Loin Roast 0
# Bacon 0
# Ham, smoked 0
# Salt Pork 0
# Roasting Chicken 46
# Veal Cutlets 0
# Salmon, Pink (can) 0
# Apples 544
# Bananas 498
# Lemons 952
# Oranges 1998
# Green Beans 862
# Cabbage 5369
# Carrots 608
# Celery 313
# Lettuce 449
# Onions 1184
# Potatoes 2522
# Spinach 2755
# Sweet Potatoes 1912
# Peaches (can) 196
# Pears (can) 81
# Pineapple (can) 399
# Asparagus (can) 272
# Green Beans (can) 431
# Pork and Beans (can) 0
# Corn (can) 218
# Peas (can) 370
# Tomatoes (can) 1253
# Tomato Soup (can) 862
# Peaches, Dried 57
# Prunes, Dried 257
# Raisins, Dried 136
# Peas, Dried 0
# Lima Beans, Dried 0
# Navy Beans, Dried 0
# Coffee 0
# Tea 0
# Cocoa 0
# Chocolate 0
# Sugar 0
# Corn Syrup 0
# Molasses 0
# Strawberry Preserves 0
# Number of constraints = 36

# %%
# Objective function: Minimize the sum of (price-normalized) foods.
objective = solver.Objective()
for food in foods:
    objective.SetCoefficient(food, 1)
objective.SetMinimization()

# %%
status = solver.Solve()
# Check that the problem has an optimal solution.
if status != solver.OPTIMAL:
    print('The problem does not have an optimal solution!')
    if status == solver.FEASIBLE:
        print('A potentially suboptimal solution was found.')
    else:
        print('The solver could not solve the problem.')
        exit(1)

# Display the amounts (in dollars) to purchase of each food.
nutrients_result = [0] * len(nutrients)
print('\nAnnual Foods:')
for i, food in enumerate(foods):
    if food.solution_value() > 0.0:
        print('{}: ${}'.format(data[i][0], 365. * food.solution_value()))
        for j, _ in enumerate(nutrients):
            nutrients_result[j] += data[i][j + 3] * food.solution_value()
print('\nOptimal annual price: ${:.4f}'.format(365. * objective.Value()))

print('\nNutrients per day:')
for i, nutrient in enumerate(nutrients):
    print('{}: {:.2f} (min {})'.format(nutrient[0], nutrients_result[i],
                                       nutrient[1]))
# Out:
# Annual Foods:
# Wheat Flour (Enriched): $10.774457511918223
# Liver (Beef): $0.6907834111074191
# Cabbage: $4.093268864842878
# Spinach: $1.8277960703546992
# Navy Beans, Dried: $22.27542568724303
#
# Optimal annual price: $39.6617
#
# Nutrients per day:
# Calories (kcal): 3.00 (min 3)
# Protein (g): 147.41 (min 70)
# Calcium (g): 0.80 (min 0.8)
# Iron (mg): 60.47 (min 12)
# Vitamin A (KIU): 5.00 (min 5)
# Vitamin B1 (mg): 4.12 (min 1.8)
# Vitamin B2 (mg): 2.70 (min 2.7)
# Niacin (mg): 27.32 (min 18)
# Vitamin C (mg): 75.00 (min 75)

# %% [markdown]
# ## Integer Optimization

# %% [markdown]
# ### MIP Problem

# %%
from ortools.linear_solver import pywraplp

# %%
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver('SCIP')

# %%
infinity = solver.infinity()
# x and y are integer non-negative variables.
x = solver.IntVar(0.0, infinity, 'x')
y = solver.IntVar(0.0, infinity, 'y')

print('Number of variables =', solver.NumVariables())
# Out:
# Number of variables = 2

# %%
# x + 7 * y <= 17.5.
solver.Add(x + 7 * y <= 17.5)
# x <= 3.5.
solver.Add(x <= 3.5)
print('Number of constraints =', solver.NumConstraints())
# Out:
# Number of constraints = 2

# %%
# Maximize x + 10 * y.
solver.Maximize(x + 10 * y)

# %%
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Objective value =', solver.Objective().Value())
    print('x =', x.solution_value())
    print('y =', y.solution_value())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Solution:
# Objective value = 23.0
# x = 3.0
# y = 2.0

# %% [markdown]
# ### Array to define a Model

# %%
def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['constraint_coeffs'] = [
        [5, 7, 9, 2, 1],
        [18, 4, -9, 10, 12],
        [4, 7, 3, 8, 5],
        [5, 13, 16, 3, -7],
    ]
    data['bounds'] = [250, 285, 211, 315]
    data['obj_coeffs'] = [7, 8, 2, 9, 6]
    data['num_vars'] = 5
    data['num_constraints'] = 4
    return data

# %%
data = create_data_model()

# %%
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver('SCIP')

# %%
infinity = solver.infinity()
x = {}
for j in range(data['num_vars']):
    x[j] = solver.IntVar(0, infinity, 'x[%i]' % j)
print('Number of variables =', solver.NumVariables())
# Out:
# Number of variables = 5

# %%
for i in range(data['num_constraints']):
    constraint = solver.RowConstraint(0, data['bounds'][i], '')
    for j in range(data['num_vars']):
        constraint.SetCoefficient(x[j], data['constraint_coeffs'][i][j])
print('Number of constraints =', solver.NumConstraints())
# In Python, you can also set the constraints as follows.
# for i in range(data['num_constraints']):
#  constraint_expr = \
# [data['constraint_coeffs'][i][j] * x[j] for j in range(data['num_vars'])]
#  solver.Add(sum(constraint_expr) <= data['bounds'][i])
# Out:
# Number of constraints = 4

# %%
objective = solver.Objective()
for j in range(data['num_vars']):
    objective.SetCoefficient(x[j], data['obj_coeffs'][j])
objective.SetMaximization()
# In Python, you can also set the objective as follows.
# obj_expr = [data['obj_coeffs'][j] * x[j] for j in range(data['num_vars'])]
# solver.Maximize(solver.Sum(obj_expr))

# %%
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL:
    print('Objective value =', solver.Objective().Value())
    for j in range(data['num_vars']):
        print(x[j].name(), ' = ', x[j].solution_value())
    print()
    print('Problem solved in %f milliseconds' % solver.wall_time())
    print('Problem solved in %d iterations' % solver.iterations())
    print('Problem solved in %d branch-and-bound nodes' % solver.nodes())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Objective value = 260.0000000000005
# x[0]  =  8.0
# x[1]  =  21.0
# x[2]  =  0.0
# x[3]  =  2.0
# x[4]  =  3.0
#
# Problem solved in 91126.000000 milliseconds
# Problem solved in 55 iterations
# Problem solved in 7 branch-and-bound nodes

# %% [markdown]
# ### Test

# %% [markdown]
# ## Constraint Optimization

# %% [markdown]
# ### CP-SAT Solver

# %%
from ortools.sat.python import cp_model

# %%
model = cp_model.CpModel()

# %%
num_vals = 3
x = model.NewIntVar(0, num_vals - 1, 'x')
y = model.NewIntVar(0, num_vals - 1, 'y')
z = model.NewIntVar(0, num_vals - 1, 'z')

# %%
model.Add(x != y)

# %%
solver = cp_model.CpSolver()
status = solver.Solve(model)
if status == cp_model.FEASIBLE or status == cp_model.OPTIMAL:
    print('x = %i' % solver.Value(x))
    print('y = %i' % solver.Value(y))
    print('z = %i' % solver.Value(z))
# Out:
# x = 1
# y = 0
# z = 0

# %%
class VarArraySolutionPrinter(cp_model.CpSolverSolutionCallback):
    """Print intermediate solutions."""

    def __init__(self, variables):
        cp_model.CpSolverSolutionCallback.__init__(self)
        self.__variables = variables
        self.__solution_count = 0

    def on_solution_callback(self):
        self.__solution_count += 1
        for v in self.__variables:
            print('%s=%i' % (v, self.Value(v)), end=' ')
        print()

    def solution_count(self):
        return self.__solution_count

# %%
solver = cp_model.CpSolver()
solution_printer = VarArraySolutionPrinter([x, y, z])
status = solver.SearchForAllSolutions(model, solution_printer)
# Out:
# x=1 y=2 z=0
# x=1 y=0 z=0
# x=2 y=0 z=0
# x=2 y=1 z=0
# x=2 y=1 z=1
# x=2 y=0 z=1
# x=1 y=0 z=1
# x=1 y=2 z=1
# x=1 y=2 z=2
# x=1 y=0 z=2
# x=2 y=0 z=2
# x=2 y=1 z=2
# x=0 y=1 z=2
# x=0 y=1 z=1
# x=0 y=1 z=0
# x=0 y=2 z=0
# x=0 y=2 z=1
# x=0 y=2 z=2

# %% [markdown]
# ### Solving a CP Problem

# %%
from ortools.sat.python import cp_model
def main():
  model = cp_model.CpModel()

# %%
var_upper_bound = max(50, 45, 37)
x = model.NewIntVar(0, var_upper_bound, 'x')
y = model.NewIntVar(0, var_upper_bound, 'y')
z = model.NewIntVar(0, var_upper_bound, 'z')

# %%
model.Add(2*x + 7*y + 3*z <= 50)
model.Add(3*x - 5*y + 7*z <= 45)
model.Add(5*x + 2*y - 6*z <= 37)

# %% [markdown]
# ### Cryptarithmetic

# %% [markdown]
# ### N Queens Problem

# %% [markdown]
# ### Setting Solver Limits

# %% [markdown]
# ### Original CP Solver
