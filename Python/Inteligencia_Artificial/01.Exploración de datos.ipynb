# %% [markdown]
# # Exploración de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as ss

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data.shape
# Out:
# (400, 5)

# %%
data.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
data.dtypes
# Out:
# User ID              int64
# Gender              object
# Age                float64
# EstimatedSalary    float64
# Purchased            int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    float64
#  3   EstimatedSalary  400 non-null    float64
#  4   Purchased        400 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
#1.Análisis Univariado

#media
data['Age'].mean()
# Out:
# 37.655

# %%
#mediana
data['Age'].median()
# Out:
# 37.0

# %%
#moda
data['Age'].mode()
# Out:
# 0    35.0
# dtype: float64

# %%
#cuartiles
data['Age'].quantile()
# Out:
# 37.0

# %%
data['Age'].quantile([0])
# Out:
# 0.0    18.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([1])
# Out:
# 1.0    60.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.25])
# Out:
# 0.25    29.75
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.50])
# Out:
# 0.5    37.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.75])
# Out:
# 0.75    46.0
# Name: Age, dtype: float64

# %%
#decil
data['Age'].quantile([0.10])
# Out:
# 0.1    24.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.20])
# Out:
# 0.2    28.0
# Name: Age, dtype: float64

# %%
data['Age'].quantile([0.90])
# Out:
# 0.9    52.1
# Name: Age, dtype: float64

# %%
#rango
data['Age'].min()
# Out:
# 18

# %%
data['Age'].max()
# Out:
# 60

# %%
data['Age'].max()-data['Age'].min()
# Out:
# 42

# %%
#rango intercuartílico
data['Age'].quantile(0.75)-data['Age'].quantile(0.25)
# Out:
# 16.25

# %%
#varianza
data['Age'].var()
# Out:
# 109.89070175438596

# %%
#desviación estándar
data['Age'].std()
# Out:
# 10.482876597307914

# %%
data['Age'].std(ddof=0) #poblacional
# Out:
# 10.46976480156073

# %%
data['Age'].std(ddof=1) #muestral
# Out:
# 10.482876597307914

# %%
#coeficiente de variación
data['Age'].std(ddof=0)/data['Age'].mean()
# Out:
# 0.278044477534477

# %%
#coeficiente de asimetría
ss.skew(data['Age'])
# Out:
# 0.23046904236325927

# %%
#coeficiente de curtosis
ss.kurtosis(data['Age'])
# Out:
# -0.6297213829600437

# %%
#resumen
data['Age'].describe()
# Out:
# count    400.000000
# mean      37.655000
# std       10.482877
# min       18.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
data['EstimatedSalary'].describe()
# Out:
# count       400.000000
# mean      69742.500000
# std       34096.960282
# min       15000.000000
# 25%       43000.000000
# 50%       70000.000000
# 75%       88000.000000
# max      150000.000000
# Name: EstimatedSalary, dtype: float64

# %%
#Prueba de normalidad
ss.shapiro(data.EstimatedSalary)
# Out:
# ShapiroResult(statistic=0.9600138068199158, pvalue=5.734485331032602e-09)

# %%
ss.normaltest(data.EstimatedSalary)
# Out:
# NormaltestResult(statistic=19.18964958710917, pvalue=6.808015523241932e-05)

# %%
#2.Análisis Bivariado
# coeficiente de correlación
data.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
data.corr(method = "pearson")
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
data.corr(method = "spearman")
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.002494         0.066768   0.006980
# Age             -0.002494  1.000000         0.124824   0.612323
# EstimatedSalary  0.066768  0.124824         1.000000   0.306858
# Purchased        0.006980  0.612323         0.306858   1.000000

# %%
data.corr(method = "kendall")
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.030175         0.034737  -0.535589
# Age             -0.030175  1.000000         0.071278  -0.200627
# EstimatedSalary  0.034737  0.071278         1.000000  -0.369273
# Purchased       -0.535589 -0.200627        -0.369273   1.000000

# %%
ss.pearsonr(data['Age'],data['EstimatedSalary'])
# Out:
# (0.15523801797210005, 0.001846056800579736)

# %%
ss.spearmanr(data['Age'],data['EstimatedSalary'])
# Out:
# SpearmanrResult(correlation=0.12482434405192087, pvalue=0.01247367042800823)

# %%
ss.kendalltau(data['Age'],data['EstimatedSalary'])
# Out:
# KendalltauResult(correlation=0.08368633489101734, pvalue=0.014197892722130722)

# %%
np.corrcoef(data['Age'],data['EstimatedSalary'])
# Out:
# array([[1.        , 0.15523802],
#        [0.15523802, 1.        ]])

# %%
#3.Visualización de datos

#Histograma
data['Age'].plot(kind='hist',bins=10,title='Age',subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>], dtype=object)

# %%
data['Age'].hist(bins=10) 
plt.xlabel("Edad en años")
plt.ylabel("Frecuencia")
plt.show()

# %%
data['EstimatedSalary'].plot(kind='hist',bins=10,title='Salary',subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>], dtype=object)

# %%
sns.distplot(data['EstimatedSalary'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Density'>

# %%
#Densidad
data['Age'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data['Age'],shade=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#Boxplot
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d9cd4cc070>,
#   <matplotlib.lines.Line2D at 0x1d9cd4cc370>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d9cd4cc6d0>,
#   <matplotlib.lines.Line2D at 0x1d9cd4cca30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d9cd4becd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d9cd4ccd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d9cd4d9130>],
#  'means': []}

# %%
sns.boxplot(list(data['Age']))
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.boxplot(x='Age',data=data)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(y='Age',data=data)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(x='Purchased',y='Age',data=data)
# Out:
# <AxesSubplot:xlabel='Purchased', ylabel='Age'>

# %%
sns.boxplot(x='Purchased',y='EstimatedSalary',data=data)
# Out:
# <AxesSubplot:xlabel='Purchased', ylabel='EstimatedSalary'>

# %%
#Violin Plot
sns.violinplot(y='Age',data=data)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.violinplot(x='Purchased',y='Age',data=data)
# Out:
# <AxesSubplot:xlabel='Purchased', ylabel='Age'>

# %%
#Swarm Plot
sns.swarmplot(data['Age'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.swarmplot(x=data['EstimatedSalary'])
# Out:
# <AxesSubplot:xlabel='EstimatedSalary'>

# %%
sns.swarmplot(y=data['EstimatedSalary'])
# Out:
# <AxesSubplot:ylabel='EstimatedSalary'>

# %%
sns.swarmplot(y=data['EstimatedSalary'],x=data['Purchased'])
# Out:
# <AxesSubplot:xlabel='Purchased', ylabel='EstimatedSalary'>

# %%
#Gráfico de dispersión
data.plot(kind='scatter', x='Age', y='EstimatedSalary')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
plt.scatter(data['Age'],data['EstimatedSalary'])

# %%
plt.plot(data['Age'],data['EstimatedSalary'],"ro")

# %%
#Heatmap
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.matshow(data.corr())

# %%
#Resumen
sns.pairplot(data)

# %%
#Bar Chart
data['Purchased'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data['Purchased'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Purchased', ylabel='count'>

# %%
#Pie Chart
plt.pie(data['Purchased'].value_counts(),labels=['0','1'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d9ce4d2cd0>,
#   <matplotlib.patches.Wedge at 0x1d9ce4e11f0>],
#  [Text(-0.47615978768185807, 0.9916006537889979, '0'),
#   Text(0.47615969484150195, -0.9916006983702906, '1')])

# %%
print(pd.crosstab(data["Purchased"],data["Gender"]))
Gender = pd.crosstab(data["Purchased"],data["Gender"])
Gender.div(Gender.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True,figsize=(4,4))
plt.xlabel("Purchased")
plt.ylabel("Percentage")
plt.show()
# Out:
# Gender     Female  Male
# Purchased
# 0             127   130
# 1              77    66
